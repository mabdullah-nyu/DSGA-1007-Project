# %% [markdown]
# TF-IDF is the original Google salient terms algorithm. It is the product of term frequency and inverse document frequency, aiming to define the importance of a keyword within a corpus.
#
# We use it here to see which non-Michelin restaurants are most closely related Michelins (per reviews).

# %% [markdown]
# # Implementation

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd
import numpy as np
import os
import json
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
current_directory = os.getcwd()
file_path = 'restaurant_reviews.csv' #Download this CSV(df_final_restaurants) via data_processing.ipynb 
df_restaurant_reviews = pd.read_csv(os.path.join(current_directory, file_path), index_col=0)
# Out:
# /var/folders/kj/3n05xf5101nd06t7q93vbtnc0000gn/T/ipykernel_62116/12045346.py:3: DtypeWarning: Columns (0,1,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_restaurant_reviews = pd.read_csv(os.path.join(current_directory, file_path), index_col=0)

# %%
#Get reviews for all restaurants into one large dictionary (restaurant : concatenated string of all its reviews).
restaurant_docs = {}
for restaurant, data in df_restaurant_reviews.groupby('restaurant'):
    restaurant_docs[restaurant] = ' '.join(data['comment.text'])

# %%
with open('michelin_alias.json') as fp:
    michelins = set(json.load(fp).values())

# %%
#Concatenate all reviews from Michelin restaurants into a "michelin document" or mega string.
michelin_doc = ' '.join(doc for restaurant, doc in restaurant_docs.items() if restaurant in michelins)

# %% [markdown]
# Now, let's use TF-IDF to determine the similarities between each restaurant "document" and the "michelin document". The idea is that the restaurants with the highest similarities are most likely to be Michelin restaurants. The high ranking restaurants that are not already Michelin might be more likely to become Michelin in the future.

# %%
aliases = ['michelin_doc'] + list(restaurant_docs.keys())
documents = [michelin_doc] + list(restaurant_docs.values())

# %%
tfidf = TfidfVectorizer().fit_transform(documents)
similarities = tfidf[0] * tfidf.T

# %% [markdown]
# Create and rank the dataframe by similarity to the "michelin document".

# %%
df_similarity = pd.DataFrame({
    "alias": aliases,
    "similarity": similarities.todense().tolist()[0], #Compare each individual restaurant to the overall Michelin reviews.
    "michelin": [a in michelins for a in aliases]
})

# %%
df_similarity.sort_values(by="similarity", ascending=False, inplace=True)
df_similarity["rank"] = range(len(df_similarity))

# %% [markdown]
# # Results

# %%
#Restaurants most similar to the "michelin document".
df_similarity.head(10)
# Out:
#                                        alias  similarity  michelin  rank
# 0                               michelin_doc    1.000000     False     0
# 1933   chefs-table-at-brooklyn-fare-new-york    0.940698     False     1
# 9810                   the-modern-new-york-3    0.940447      True     2
# 3572               gabriel-kreuther-new-york    0.932203      True     3
# 8554            sixty-three-clinton-new-york    0.932164      True     4
# 7057               one-white-street-new-york    0.932111      True     5
# 6438                  momofuku-ko-new-york-3    0.931969     False     6
# 1812     cathédrale-restaurant-new-york-city    0.930357     False     7
# 1809                      catch-nyc-new-york    0.926517     False     8
# 10386                        vestry-new-york    0.925894      True     9

# %%
top_10 = df_similarity.head(10)

plt.figure(figsize=(8, 6)) 
sns.barplot(x='rank', y='alias', hue='michelin', data=top_10, palette = {0: 'salmon', 1: 'red'})

plt.title('Top 10 Restaurants by Similarity Score')
plt.xlabel('Restaurant')
plt.ylabel('Similarity (Ranked)')
plt.annotate("Interesting: Despite losing it's 3 Michelin stars this year, unceremoniously firing its head chef, and closing shortly after, Chef's Table ranks highest.", 
             xy=(0.5, -0.15), xycoords='axes fraction',
             ha='center', va='center', fontsize=10, color='gray')
plt.show()

# %%
#Ranks of Michelin restaurants most similar to the "michelin document".
df_similarity[df_similarity["michelin"] == True].head(10)
# Out:
#                               alias  similarity  michelin  rank
# 9810          the-modern-new-york-3    0.940447      True     2
# 3572      gabriel-kreuther-new-york    0.932203      True     3
# 8554   sixty-three-clinton-new-york    0.932164      True     4
# 7057      one-white-street-new-york    0.932111      True     5
# 10386               vestry-new-york    0.925894      True     9
# 5424          le-bernardin-new-york    0.922247      True    13
# 9817       the-musket-room-new-york    0.921416      True    15
# 5481           le-pavillon-new-york    0.919724      True    16
# 7942        red-paper-clip-new-york    0.915057      True    22
# 4584        jean-georges-new-york-2    0.914246      True    25

# %%
top_10_michelins = df_similarity[df_similarity["michelin"] == True].head(10)

plt.figure(figsize=(8, 6)) 

sns.barplot(x='rank', y='alias', data=top_10_michelins,palette = "flare")

plt.title('Top 10 Michelins by Similarity Score')
plt.xlabel('Rank')
plt.ylabel('Similarity')
plt.show()

# %% [markdown]
# ## Add our data to the restaurant details dataframe for further analysis.

# %%
current_directory = os.getcwd()
file_path = 'restaurant_details.csv'
df_restaurants = pd.read_csv(os.path.join(current_directory, file_path), index_col=0)

df_restaurants = df_restaurants.merge(df_similarity, on="alias")

# %% [markdown]
# Show the restaurant with the highest similarity to the "michelin document" by group.

# %%
pd.set_option('display.max_rows', None)
def display_highest_in_group(df, group):
    display(df[["name", "similarity", "rank", "michelin", group]].groupby(group).first().sort_values(by='similarity', ascending=False))

# %%
#Cuisines with highest Michelin similarity
display_highest_in_group(df_restaurants, "category_0")
# Out:
#                                                                          name  \
# category_0
# Greek                                                                  Skinos
# Brasseries                                                         Frenchette
# Dim Sum                                                   Brooklyn Chop House
# Modern European                                                    Queensyard
# Australian                                                   Hole In The Wall
# American                                                        P.J. Clarke's
# Seafood                                                    Mezze on the River
# Argentine                                                  Porteno Restaurant
# Tapas/Small Plates                                             Terra Wine Bar
# Whiskey Bars                                         The Copper Still Chelsea
# Gastropubs                                                     The Malt House
# Coffee & Tea                                                Le Pain Quotidien
# Tuscan                                                    Pepolino Restaurant
# Indonesian                                                              Wayan
# Basque                                                                Txikito
# Steakhouses                                           Morton's The Steakhouse
# Southern                                                           Blue Smoke
# Izakaya                                                                 Saito
# Lounges                                                         Smith & Mills
# Boating                                       The Loeb Boathouse Central Park
# Latin American                                               Counter & Bodega
# Austrian                                           Schilling Restaurant & Bar
# Grocery                                                   Eataly NYC Downtown
# Bars                                             Bill's Bar & Burger Downtown
# Cajun/Creole                                                         1803 Nyc
# Pool Halls                                                             Taboga
# Chinese                                              Jiangnan Chinese Cuisine
# Hotels                                     Merrion Row Hotel and Public House
# Catalan                                                                  Leña
# Irish                                                              The Milton
# Music Venues                                          Chelsea Table and Stage
# Sandwiches                                                    Épicerie Boulud
# Olive Oil                                                 Best Sicily Bottega
# Delis                                                        Riverside Market
# Hair Salons                                            Color Matrix CafeSalon
# Poke                                                                LuLu Poke
# Bangladeshi                                                        Nirvana 54
# Colombian                                                        Cositas Cafe
# Nightlife                                                           The Lemon
# Donuts                                                           Krispy Kreme
# Georgian                                                     Supra Factor NYC
# Food                                                         Tamales Ebenezer
# Pretzels                                               Auntie Anne's Pretzels
# Halal                                                         Halal Food Cart
# Gelato                                                           Anita Gelato
# Japanese                                                             The Bowl
# Beer Bar                                             Mayhem Beer & Sandwiches
# Specialty Food                                                   Corrado Cafe
# Comfort Food                                                       Tyga Bites
# Ukrainian                                                       Veselka Essex
# Caribbean                                                        Branch Patty
# Wraps                                                        Grubbs Take Away
# Performing Arts                                          Everett Library Cafe
# British                                                  Channel 4 Restaurant
# Themed Cafes                                              Full Tank Moto Cafe
# Portuguese                                                     Joey Bats Café
# Cheesesteaks                                       Philly Cheesesteak Company
# Personal Chefs                                                  JEN'S Kitchen
# Spanish                                                               Darlene
# Macarons                                                      Woops! Bakeshop
# Cafes                                                              Illy Caffe
# Shopping Centers                                     The Atrium Shops & Cafes
# Vape Shops                                       Clinton’s Exotic Plus & Deli
# Tobacco Shops                     Nagle Deli, Smoke Shop, & Convenience Store
# Kebab                                                         Chinese Pinchos
# Souvenir Shops                                                      Lil Jay's
# Middle Eastern                                       New York Best Halal Food
# Filipino                                                          Mucho Sarap
# Venues & Event Spaces                                               W XYZ Bar
# Kosher                                                 Greenwich and Delancey
# Pop-Up Restaurants                                             Sisig Ng Bayan
# Food Tours                                                   Bob's Pizza Tour
# Supper Clubs                                                     The Darkroom
# Organic Stores                                  Evergreen Organic Food & Deli
# Pan Asian                                                              Tenzan
# Waffles                                                     Waffle Street NYC
# Soup                                                       Manhattan Soup Man
# Restaurants                                         William Street Food Court
# Pop-up Shops                                                   Ootoya Counter
# Used, Vintage & Consignment                                             Laams
# Food Delivery Services                             TriBeCa’s Home Style Diner
# Armenian                                                  Columbia Smoke Shop
# Poutineries                                           Rosie's Poutine Kitchen
# Hot Dogs                                                      Perros Y Vainas
# Street Vendors                                        New York's Best Hot Dog
#
#                               similarity   rank  michelin
# category_0
# Greek                           0.912879     32     False
# Brasseries                      0.909912     49     False
# Dim Sum                         0.904986     70     False
# Modern European                 0.900266    103     False
# Australian                      0.893199    173     False
# American                        0.892413    187     False
# Seafood                         0.889305    228     False
# Argentine                       0.882526    357     False
# Tapas/Small Plates              0.875397    514     False
# Whiskey Bars                    0.875185    517     False
# Gastropubs                      0.872076    609     False
# Coffee & Tea                    0.869112    681     False
# Tuscan                          0.866409    764     False
# Indonesian                      0.865266    800     False
# Basque                          0.864614    818     False
# Steakhouses                     0.859327    977     False
# Southern                        0.857136   1047     False
# Izakaya                         0.856227   1072     False
# Lounges                         0.854435   1129     False
# Boating                         0.849956   1274     False
# Latin American                  0.849278   1291     False
# Austrian                        0.845824   1404     False
# Grocery                         0.843471   1479     False
# Georgian                        0.517497   8594     False
# Food                            0.516054   8605     False
# Pretzels                        0.515634   8610     False
# Halal                           0.515215   8617     False
# Gelato                          0.514441   8625     False
# Japanese                        0.511404   8648     False
# Beer Bar                        0.509461   8673     False
# Specialty Food                  0.508259   8688     False
# Comfort Food                    0.504518   8713     False
# Ukrainian                       0.493479   8817     False
# Caribbean                       0.484249   8907     False
# Wraps                           0.481115   8936     False
# Performing Arts                 0.476645   8981     False
# British                         0.467886   9033     False
# Themed Cafes                    0.455257   9141     False
# Portuguese                      0.447349   9204     False
# Cheesesteaks                    0.444518   9228     False
# Personal Chefs                  0.440938   9252     False
# Spanish                         0.435259   9297     False
# Macarons                        0.429743   9340     False
# Cafes                           0.421704   9390     False
# Shopping Centers                0.417887   9415     False
# Vape Shops                      0.411511   9454     False
# Tobacco Shops                   0.385294   9627     False
# Kebab                           0.377178   9675     False
# Souvenir Shops                  0.368673   9736     False
# Middle Eastern                  0.359175   9813     False
# Filipino                        0.358526   9821     False
# Venues & Event Spaces           0.353385   9857     False
# Kosher                          0.322227  10020     False
# Pop-Up Restaurants              0.319113  10035     False
# Food Tours                      0.305745  10087     False
# Supper Clubs                    0.285702  10173     False
# Organic Stores                  0.268666  10252     False
# Pan Asian                       0.259430  10305     False
# Waffles                         0.252840  10331     False
# Soup                            0.245396  10364     False
# Restaurants                     0.225366  10443     False
# Pop-up Shops                    0.220574  10461     False
# Used, Vintage & Consignment     0.203954  10540     False
# Food Delivery Services          0.174036  10637     False
# Armenian                        0.171313  10650     False
# Poutineries                     0.118479  10783     False
# Hot Dogs                        0.108312  10808     False
# Street Vendors                  0.077744  10848     False

# %%
bin_size = 1000
bins = range(0, df_restaurants['review_count'].max() + bin_size, bin_size)
labels = [f'{i}-{i+bin_size-1}' for i in bins[:-1]]

df_restaurants['review_cnt_bins'] = pd.cut(df_restaurants['review_count'], bins=bins, labels=labels)

# %%
#Bins of review counts with strongest Michelin similarity 
display_highest_in_group(df_restaurants, "review_cnt_bins")
# Out:
#                                 name  similarity    rank  michelin
# review_cnt_bins
# 4000-4999                   Buddakan    0.880944   393.0       0.0
# 3000-3999                  Cafeteria    0.874631   536.0       0.0
# 0-999              Le Pain Quotidien    0.869112   681.0       0.0
# 1000-1999        Eataly NYC Downtown    0.843471  1479.0       0.0
# 7000-7999             Joe's Shanghai    0.819851  2284.0       0.0
# 6000-6999           Lombardi's Pizza    0.764118  4264.0       0.0
# 15000-15999      Katz's Delicatessen    0.740018  5016.0       0.0
# 10000-10999                Ippudo NY    0.732199  5217.0       0.0
# 2000-2999           NY Pizza Suprema    0.699823  6038.0       0.0
# 5000-5999        Prince Street Pizza    0.689140  6284.0       0.0
# 8000-8999                       None         NaN     NaN       NaN
# 9000-9999                       None         NaN     NaN       NaN
# 11000-11999                     None         NaN     NaN       NaN
# 12000-12999                     None         NaN     NaN       NaN
# 13000-13999                     None         NaN     NaN       NaN
# 14000-14999                     None         NaN     NaN       NaN
